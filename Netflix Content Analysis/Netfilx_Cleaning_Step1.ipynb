# %%
# STEP 1 — Netflix Data Cleaning & Feature Engineering
# File: step1_clean_data.py
# Libraries used: pandas, numpy
# Run: python step1_clean_data.py
# Input:  NetFlix.csv
# Output: cleaned_netflix.csv
#         genres_exploded.csv
#         countries_exploded.csv
#         netflix_for_excel.xlsx   (9 sheets — connect directly to Power BI)

# %%
import pandas as pd
import numpy as np

# %%
print("Loading NetFlix.csv ...")
df = pd.read_csv("NetFlix.csv")
print(f"  Loaded {len(df):,} rows x {len(df.columns)} columns")

print("\nNull counts before cleaning:")
print(df.isnull().sum())
df.info()
# Out:
# Loading NetFlix.csv ...
#   Loaded 7,787 rows x 12 columns
#
# Null counts before cleaning:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# genres             0
# description        0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   int64
#  10  genres        7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 730.2+ KB

# %%
df.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# 0  14-Aug-20          2020  TV-MA         4
# 1  15-Dec-17          2008  TV-MA       143
# 2   5-Jan-19          2016  TV-PG       124
# 3   1-Mar-16          2016      R        90
# 4   3-Dec-18          2017   TV-G         1
#
#                                               genres  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     Horror Movies, International Movies, Thrillers
# 2        Dramas, International Movies, Sports Movies
# 3                                           Comedies
# 4  British TV Shows, Docuseries, Science & Nature TV
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  An architect and his wife move into a castle t...
# 2  Three Indonesian women break records by becomi...
# 3  New NFL star Thad buys his old teammates' belo...
# 4  This sequel to the award-winning nature series...

# %%
# ── 2. DATE PARSING ─────────────────────────────────────────
# date_added is stored as "14-Aug-20" (string) -> parse to datetime
## errors="coerce"===> if datetime format invalid formatted instead of giving an error it will just conert it into NAT(not a time)
df["date_added"] = pd.to_datetime(df["date_added"], format="%d-%b-%y", errors="coerce")
### .dt==> is used to used to access the date time features 
df["year_added"]  = df["date_added"].dt.year.astype("Int64")
df["month_added"] = df["date_added"].dt.month.astype("Int64")
df["month_name"]  = df["date_added"].dt.strftime("%B")

print(f"\n  date_added parsed. Failed rows: {df['year_added'].isna().sum()}")
# Out:
#   date_added parsed. Failed rows: 98

# %%
df.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# 0 2020-08-14          2020  TV-MA         4
# 1 2017-12-15          2008  TV-MA       143
# 2 2019-01-05          2016  TV-PG       124
# 3 2016-03-01          2016      R        90
# 4 2018-12-03          2017   TV-G         1
#
#                                               genres  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     Horror Movies, International Movies, Thrillers
# 2        Dramas, International Movies, Sports Movies
# 3                                           Comedies
# 4  British TV Shows, Docuseries, Science & Nature TV
#
#                                          description  year_added  month_added  \
# 0  In a future where the elite inhabit an island ...        2020            8
# 1  An architect and his wife move into a castle t...        2017           12
# 2  Three Indonesian women break records by becomi...        2019            1
# 3  New NFL star Thad buys his old teammates' belo...        2016            3
# 4  This sequel to the award-winning nature series...        2018           12
#
#   month_name
# 0     August
# 1   December
# 2    January
# 3      March
# 4   December

# %%
df['date_added'].unique()
# Out:
# <DatetimeArray>
# ['2020-08-14 00:00:00', '2017-12-15 00:00:00', '2019-01-05 00:00:00',
#  '2016-03-01 00:00:00', '2018-12-03 00:00:00', '2019-02-25 00:00:00',
#  '2021-01-01 00:00:00', '2018-07-05 00:00:00', '2021-01-08 00:00:00',
#  '2017-12-31 00:00:00',
#  ...
#  '2020-06-08 00:00:00', '2012-02-21 00:00:00', '2020-05-24 00:00:00',
#  '2018-04-07 00:00:00', '2014-12-05 00:00:00', '2018-03-26 00:00:00',
#  '2018-06-28 00:00:00', '2017-07-02 00:00:00', '2017-08-09 00:00:00',
#  '2017-08-28 00:00:00']
# Length: 1498, dtype: datetime64[ns]

# %%
df[df["date_added"].isnull()]
# Out:
#      show_id     type                        title director  \
# 47     s1040  TV Show                 Bondi Rescue      NaN
# 56     s1049  TV Show                   Borderline      NaN
# 84     s1074  TV Show                  Brain Games      NaN
# 167    s1149  TV Show                   Burnistoun      NaN
# 326    s1292  TV Show             Chasing Monsters      NaN
# ...      ...      ...                          ...      ...
# 7249   s7523  TV Show   Weird Wonders of the World      NaN
# 7394   s7654  TV Show            Women Behind Bars      NaN
# 7589    s820  TV Show  Being Mary Jane: The Series      NaN
# 7681    s903  TV Show     Big Dreams, Small Spaces      NaN
# 7723    s941  TV Show                       Bitten      NaN
#
#                                                    cast         country  \
# 47    Andrew Günsberg, Dean Gladstone, Bruce Hopkins...       Australia
# 56    David Avery, Jackie Clune, David Elms, Liz Kin...  United Kingdom
# 84                                          Jason Silva   United States
# 167   Iain Connell, Robert Florence, Kirsty Strain, ...  United Kingdom
# 326                                      Cyril Chauquet          Canada
# ...                                                 ...             ...
# 7249                                      Chris Packham  United Kingdom
# 7394                                                NaN   United States
# 7589  Gabrielle Union, Lisa Vidal, Margaret Avery, O...   United States
# 7681                                          Monty Don  United Kingdom
# 7723  Laura Vandervoort, Greyston Holt, Greg Bryk, S...          Canada
#
#      date_added  release_year rating  duration  \
# 47          NaT          2016  TV-PG         1
# 56          NaT          2017  TV-14         2
# 84          NaT          2016   TV-G         3
# 167         NaT          2012  TV-MA         2
# 326         NaT          2016  TV-PG         2
# ...         ...           ...    ...       ...
# 7249        NaT          2016  TV-PG         2
# 7394        NaT          2010  TV-14         3
# 7589        NaT          2016  TV-14         4
# 7681        NaT          2017   TV-G         3
# 7723        NaT          2016  TV-MA         3
#
#                                                  genres  \
# 47                                           Reality TV
# 56                        British TV Shows, TV Comedies
# 84                      Docuseries, Science & Nature TV
# 167                       British TV Shows, TV Comedies
# 326         Docuseries, Reality TV, Science & Nature TV
# ...                                                 ...
# 7249  British TV Shows, Docuseries, Science & Nature TV
# 7394                         Crime TV Shows, Docuseries
# 7589                       Romantic TV Shows, TV Dramas
# 7681  British TV Shows, International TV Shows, Real...
# 7723       International TV Shows, TV Dramas, TV Horror
#
#                                             description  year_added  \
# 47    This reality series follows elite professional...        <NA>
# 56    A team of inept border agents tackles immigrat...        <NA>
# 84    This interactive series uses games, illusions ...        <NA>
# 167   This sketch series focuses on the eccentric ch...        <NA>
# 326   Adventurer Cyril Chauquet seeks out the most c...        <NA>
# ...                                                 ...         ...
# 7249  From animal oddities and bizarre science to me...        <NA>
# 7394  This reality series recounts true stories of w...        <NA>
# 7589  Ambitious single TV journalist Mary Jane attem...        <NA>
# 7681  Writer and presenter Monty Don helps England's...        <NA>
# 7723  Elena Michaels tries to stray from the pack of...        <NA>
#
#       month_added month_name
# 47           <NA>        NaN
# 56           <NA>        NaN
# 84           <NA>        NaN
# 167          <NA>        NaN
# 326          <NA>        NaN
# ...           ...        ...
# 7249         <NA>        NaN
# 7394         <NA>        NaN
# 7589         <NA>        NaN
# 7681         <NA>        NaN
# 7723         <NA>        NaN
#
# [98 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7689 non-null   datetime64[ns]
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   int64
#  10  genres        7787 non-null   object
#  11  description   7787 non-null   object
#  12  year_added    7689 non-null   Int64
#  13  month_added   7689 non-null   Int64
#  14  month_name    7689 non-null   object
# dtypes: Int64(2), datetime64[ns](1), int64(2), object(10)
# memory usage: 927.9+ KB

# %%
# ── 3. HANDLE NULLS ──────────────────────────────────────────
df["director"] = df["director"].fillna("Unknown")   # 2389 nulls
df["cast"]     = df["cast"].fillna("Unknown")        # 718 nulls
df["country"]  = df["country"].fillna("Unknown")     # 507 nulls
df = df.dropna(subset=["rating"])       # drop 7 rows with null rating
df = df.dropna(subset=["date_added"])   # drop rows where date parse failed
print(f"  Rows after null handling: {len(df):,}")
# Out:
#   Rows after null handling: 7,682

# %%
df["duration"].unique()
# Out:
# array([  4, 143, 124,  90,   1,  94, 112, 129,  85, 108,  60, 164,  97,
#         47,  99,  83, 168, 116,  53, 106, 130, 161, 111,   6,  26,  92,
#         93, 102,  89, 123,  86,  88, 126, 117,  91,   3,  79,  96,  70,
#         87,  74, 139,   2,  84, 100,  80, 105, 114,  63,  51,   5,  81,
#         77,  61, 110, 103, 118,  95, 133, 120, 155,  14,  73,  98, 119,
#         76, 104, 148,  78, 128, 122, 177, 135, 127, 151, 125, 101,  11,
#         22,   9,  46, 142, 131, 113,  67,  82, 145, 141,  75, 107, 156,
#        132, 166, 121, 115,  71,  62,  25, 146,  66,  55,  65, 137,  59,
#         56,  34, 158, 109,  69, 172,   7,   8,  57,  28,  13,  52,  45,
#         12, 176,  40,  58, 153,  64,  10, 149,  43,  68, 140,  50,  29,
#        136, 157,  23, 165, 185, 174, 154, 134, 200, 144,  21, 169,  27,
#         42, 162, 170,  48, 196,  49, 163,  20,  54, 150,  33,  72, 181,
#        204,  44,  32,  35, 167,  30,  16, 138, 179, 193,  24, 147, 214,
#         17,  38, 173, 192, 209, 171, 187,  41, 160, 182, 224,  37, 233,
#        189, 152,  19,  15, 208, 237,  31, 159, 178, 230, 194, 228, 195,
#         18, 186, 205, 190,  36, 201, 253, 180, 203, 191, 312], dtype=int64)

# %%
# ── 4. DURATION SPLIT ────────────────────────────────────────
# duration is numeric: movies = minutes (e.g. 143), TV shows = seasons (e.g. 4)
df["duration_minutes"] = np.where(df["type"] == "Movie",  df["duration"], np.nan)
df["duration_seasons"] = np.where(df["type"] == "TV Show", df["duration"], np.nan)

# %%
df.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%         Unknown
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II         Unknown
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# 0 2020-08-14          2020  TV-MA         4
# 1 2017-12-15          2008  TV-MA       143
# 2 2019-01-05          2016  TV-PG       124
# 3 2016-03-01          2016      R        90
# 4 2018-12-03          2017   TV-G         1
#
#                                               genres  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     Horror Movies, International Movies, Thrillers
# 2        Dramas, International Movies, Sports Movies
# 3                                           Comedies
# 4  British TV Shows, Docuseries, Science & Nature TV
#
#                                          description  year_added  month_added  \
# 0  In a future where the elite inhabit an island ...        2020            8
# 1  An architect and his wife move into a castle t...        2017           12
# 2  Three Indonesian women break records by becomi...        2019            1
# 3  New NFL star Thad buys his old teammates' belo...        2016            3
# 4  This sequel to the award-winning nature series...        2018           12
#
#   month_name  duration_minutes  duration_seasons
# 0     August               NaN               4.0
# 1   December             143.0               NaN
# 2    January             124.0               NaN
# 3      March              90.0               NaN
# 4   December               NaN               1.0

# %%
df['rating'].unique()
# Out:
# array(['TV-MA', 'TV-PG', 'R', 'TV-G', 'PG-13', 'TV-14', 'TV-Y', 'PG',
#        'TV-Y7', 'NR', 'G', 'TV-Y7-FV', 'UR', 'NC-17'], dtype=object)

# %%
# Rating	    Meaning	                    Audience
# TV-Y	    Suitable for all children	    Kids 
# TV-Y7	    For kids 7+	                    Kids
# TV-Y7-FV	Kids 7+, fantasy violence	    Kids
# TV-G	    General audience	            Kids/Family
# G	        General audience (movies)	    Kids
# PG	    Parental guidance suggested	    Family 
# TV-PG	    Parental guidance TV	        Family
# PG-13	    Parents strongly cautioned	    Teens 
# TV-14	    Suitable for 14+	            Teens
# R	     Restricted (17+ with adult)	    Adults 
# TV-MA	    Mature audience only	        Adults
# NC-17	    Adults only (strict)	        Adults
# NR	    Not Rated	                    Unknown
# UR	    Unrated	                        Unknown

# %% [markdown]
# <!--
# Rating	    Meaning	                        Audience
# TV-Y	    Suitable for all children	    Kids 👶
# TV-Y7	    For kids 7+	                    Kids
# TV-Y7-FV	Kids 7+, fantasy violence	    Kids
# TV-G	    General audience	            Kids/Family
# G	        General audience (movies)	    Kids
# PG	        Parental guidance suggested	    Family 👨‍👩‍👧
# TV-PG	    Parental guidance TV	        Family
# PG-13	    Parents strongly cautioned	    Teens 👦
# TV-14	    Suitable for 14+	            Teens
# R	        Restricted (17+ with adult)	    Adults 🔞
# TV-MA	    Mature audience only	        Adults
# NC-17	    Adults only (strict)	        Adults
# NR	        Not Rated	                    Unknown
# UR	        Unrated	Unknown -->

# %%
# ── 5. AUDIENCE GROUP ────────────────────────────────────────
rating_map = {
    "TV-G"    : "Kids",    "TV-Y"  : "Kids",
    "TV-Y7"   : "Kids",    "TV-Y7-FV": "Kids",  "G": "Kids",
    "PG"      : "Family",  "TV-PG" : "Family",
    "PG-13"   : "Teens",   "TV-14" : "Teens",
    "R"       : "Adults",  "TV-MA" : "Adults",  "NC-17": "Adults",
    "NR"      : "Unrated", "UR"    : "Unrated",
}
df["audience_group"] = df["rating"].map(rating_map).fillna("Unrated")

# %%
df.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%         Unknown
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II         Unknown
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# 0 2020-08-14          2020  TV-MA         4
# 1 2017-12-15          2008  TV-MA       143
# 2 2019-01-05          2016  TV-PG       124
# 3 2016-03-01          2016      R        90
# 4 2018-12-03          2017   TV-G         1
#
#                                               genres  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     Horror Movies, International Movies, Thrillers
# 2        Dramas, International Movies, Sports Movies
# 3                                           Comedies
# 4  British TV Shows, Docuseries, Science & Nature TV
#
#                                          description  year_added  month_added  \
# 0  In a future where the elite inhabit an island ...        2020            8
# 1  An architect and his wife move into a castle t...        2017           12
# 2  Three Indonesian women break records by becomi...        2019            1
# 3  New NFL star Thad buys his old teammates' belo...        2016            3
# 4  This sequel to the award-winning nature series...        2018           12
#
#   month_name  duration_minutes  duration_seasons audience_group
# 0     August               NaN               4.0         Adults
# 1   December             143.0               NaN         Adults
# 2    January             124.0               NaN         Family
# 3      March              90.0               NaN         Adults
# 4   December               NaN               1.0           Kids

# %%
# ── 6. CONTENT AGE ───────────────────────────────────────────
# Years between original release and when added to Netflix
##it means that when the movie got added on the netflix after the releasing of movie example==> 2016(add)-2013(realease)=3 years 
df["content_age_at_add"] = df["year_added"] - df["release_year"]

# %%
df.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%         Unknown
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II         Unknown
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# 0 2020-08-14          2020  TV-MA         4
# 1 2017-12-15          2008  TV-MA       143
# 2 2019-01-05          2016  TV-PG       124
# 3 2016-03-01          2016      R        90
# 4 2018-12-03          2017   TV-G         1
#
#                                               genres  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     Horror Movies, International Movies, Thrillers
# 2        Dramas, International Movies, Sports Movies
# 3                                           Comedies
# 4  British TV Shows, Docuseries, Science & Nature TV
#
#                                          description  year_added  month_added  \
# 0  In a future where the elite inhabit an island ...        2020            8
# 1  An architect and his wife move into a castle t...        2017           12
# 2  Three Indonesian women break records by becomi...        2019            1
# 3  New NFL star Thad buys his old teammates' belo...        2016            3
# 4  This sequel to the award-winning nature series...        2018           12
#
#   month_name  duration_minutes  duration_seasons audience_group  \
# 0     August               NaN               4.0         Adults
# 1   December             143.0               NaN         Adults
# 2    January             124.0               NaN         Family
# 3      March              90.0               NaN         Adults
# 4   December               NaN               1.0           Kids
#
#    content_age_at_add
# 0                   0
# 1                   9
# 2                   3
# 3                   0
# 4                   1

# %%
df
# Out:
#      show_id     type                                      title  \
# 0         s1  TV Show                                         3%
# 1        s10    Movie                                       1920
# 2       s100    Movie                                 3 Heroines
# 3      s1000    Movie  Blue Mountain State: The Rise of Thadland
# 4      s1001  TV Show                             Blue Planet II
# ...      ...      ...                                        ...
# 7782    s995  TV Show                                 Blown Away
# 7783    s996  TV Show                              Blue Exorcist
# 7784    s997    Movie                  Blue Is the Warmest Color
# 7785    s998    Movie                               Blue Jasmine
# 7786    s999    Movie                                   Blue Jay
#
#                  director                                               cast  \
# 0                 Unknown  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1            Vikram Bhatt  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...
# 2          Iman Brotoseno  Reza Rahadian, Bunga Citra Lestari, Tara Basro...
# 3            Lev L. Spiro  Alan Ritchson, Darin Brooks, James Cade, Rob R...
# 4                 Unknown                                 David Attenborough
# ...                   ...                                                ...
# 7782              Unknown                                            Unknown
# 7783              Unknown  Nobuhiko Okamoto, Jun Fukuyama, Kana Hanazawa,...
# 7784  Abdellatif Kechiche  Léa Seydoux, Adèle Exarchopoulos, Salim Kechio...
# 7785          Woody Allen  Cate Blanchett, Sally Hawkins, Alec Baldwin, L...
# 7786         Alex Lehmann           Sarah Paulson, Mark Duplass, Clu Gulager
#
#                      country date_added  release_year rating  duration  \
# 0                     Brazil 2020-08-14          2020  TV-MA         4
# 1                      India 2017-12-15          2008  TV-MA       143
# 2                  Indonesia 2019-01-05          2016  TV-PG       124
# 3              United States 2016-03-01          2016      R        90
# 4             United Kingdom 2018-12-03          2017   TV-G         1
# ...                      ...        ...           ...    ...       ...
# 7782                  Canada 2019-07-12          2019  TV-14         1
# 7783                   Japan 2020-09-01          2017  TV-MA         2
# 7784  France, Belgium, Spain 2016-08-26          2013  NC-17       180
# 7785           United States 2019-03-08          2013  PG-13        98
# 7786           United States 2016-12-06          2016  TV-MA        81
#
#                                                  genres  \
# 0     International TV Shows, TV Dramas, TV Sci-Fi &...
# 1        Horror Movies, International Movies, Thrillers
# 2           Dramas, International Movies, Sports Movies
# 3                                              Comedies
# 4     British TV Shows, Docuseries, Science & Nature TV
# ...                                                 ...
# 7782                 International TV Shows, Reality TV
# 7783               Anime Series, International TV Shows
# 7784   Dramas, Independent Movies, International Movies
# 7785               Comedies, Dramas, Independent Movies
# 7786        Dramas, Independent Movies, Romantic Movies
#
#                                             description  year_added  \
# 0     In a future where the elite inhabit an island ...        2020
# 1     An architect and his wife move into a castle t...        2017
# 2     Three Indonesian women break records by becomi...        2019
# 3     New NFL star Thad buys his old teammates' belo...        2016
# 4     This sequel to the award-winning nature series...        2018
# ...                                                 ...         ...
# 7782  Ten master artists turn up the heat in glassbl...        2019
# 7783  Determined to throw off the curse of being Sat...        2020
# 7784  Determined to fall in love, 15-year-old Adele ...        2016
# 7785  The high life leads to high anxiety for a fash...        2019
# 7786  Two former high school sweethearts unexpectedl...        2016
#
#       month_added month_name  duration_minutes  duration_seasons  \
# 0               8     August               NaN               4.0
# 1              12   December             143.0               NaN
# 2               1    January             124.0               NaN
# 3               3      March              90.0               NaN
# 4              12   December               NaN               1.0
# ...           ...        ...               ...               ...
# 7782            7       July               NaN               1.0
# 7783            9  September               NaN               2.0
# 7784            8     August             180.0               NaN
# 7785            3      March              98.0               NaN
# 7786           12   December              81.0               NaN
#
#      audience_group  content_age_at_add
# 0            Adults                   0
# 1            Adults                   9
# 2            Family                   3
# 3            Adults                   0
# 4              Kids                   1
# ...             ...                 ...
# 7782          Teens                   0
# 7783         Adults                   3
# 7784         Adults                   3
# 7785          Teens                   6
# 7786         Adults                   0
#
# [7682 rows x 19 columns]

# %%
# ── 7. SAVE CLEANED MAIN CSV ────────────────────────────────
df.to_csv("cleaned_netflix.csv", index=False)
print(f"\n  Saved cleaned_netflix.csv ({len(df):,} rows)")
# df.info()
# Out:
#   Saved cleaned_netflix.csv (7,682 rows)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'genres', 'description',
#        'year_added', 'month_added', 'month_name', 'duration_minutes',
#        'duration_seasons', 'audience_group', 'content_age_at_add'],
#       dtype='object')

# %%
# ── 8. GENRES EXPLODED ───────────────────────────────────────
print("Exploding genres ...")
g = df[["show_id","type","title","release_year","year_added",
        "rating","audience_group","genres"]].copy()
g["genre"] = g["genres"].str.split(",")
g = g.explode("genre")
g["genre"] = g["genre"].str.strip()

g = g.drop(columns=["genres"])          
g.to_csv("genres_exploded.csv", index=False)
print(f"  Saved genres_exploded.csv ({len(g):,} rows)")
# Out:
# Exploding genres ...
#   Saved genres_exploded.csv (16,859 rows)

# %%
g.head()
# Out:
#   show_id     type title  release_year  year_added rating audience_group  \
# 0      s1  TV Show    3%          2020        2020  TV-MA         Adults
# 0      s1  TV Show    3%          2020        2020  TV-MA         Adults
# 0      s1  TV Show    3%          2020        2020  TV-MA         Adults
# 1     s10    Movie  1920          2008        2017  TV-MA         Adults
# 1     s10    Movie  1920          2008        2017  TV-MA         Adults
#
#                     genre
# 0  International TV Shows
# 0               TV Dramas
# 0     TV Sci-Fi & Fantasy
# 1           Horror Movies
# 1    International Movies

# %%
# ── 9. COUNTRIES EXPLODED ────────────────────────────────────
print("Exploding countries ...")
c = df[["show_id","type","title","release_year","year_added",
        "rating","country"]].copy()
c["country_single"] = c["country"].str.split(",")
c = c.explode("country_single")
c["country_single"] = c["country_single"].str.strip()
c = c[c["country_single"] != "Unknown"]
c.to_csv("countries_exploded.csv", index=False)
print(f"  Saved countries_exploded.csv ({len(c):,} rows)")
# Out:
# Exploding countries ...
#   Saved countries_exploded.csv (8,954 rows)

# %%
# ── 10. BUILD SUMMARY TABLES (for Excel sheets) ─────────────
print("\nBuilding summary tables ...")

yearly = (df.groupby(["year_added","type"])
            .size().reset_index())
yearly.rename(columns={0:'title_count'},inplace=True)


top_genres = g["genre"].value_counts().reset_index()
top_genres.columns = ["genre", "title_count"]

top_genres_yearly = (g.groupby(["genre","year_added"])
                      .size().reset_index(name="title_count"))

top_countries = c["country_single"].value_counts().reset_index()
top_countries.columns = ["country", "title_count"]

rating_dist = (df.groupby(["rating","audience_group","type"])
                 .size().reset_index(name="title_count")
                 .sort_values("title_count", ascending=False))

monthly = (df.groupby(["year_added","month_added","month_name"])
             .size().reset_index(name="title_count"))

top_directors = (df[df["director"] != "Unknown"]
                 .groupby(["director","type"])
                 .agg(title_count=("show_id","count"),
                      first_year=("release_year","min"),
                      latest_year=("release_year","max"))
                 .reset_index()
                 .sort_values("title_count", ascending=False)
                 .head(100))

kpi = pd.DataFrame([{
    "total_titles"   : len(df),
    "total_movies"   : int((df["type"]=="Movie").sum()),
    "total_tv_shows" : int((df["type"]=="TV Show").sum()),
    "movie_pct"      : round((df["type"]=="Movie").mean() * 100, 1),
    "tv_show_pct"    : round((df["type"]=="TV Show").mean() * 100, 1),
    "unique_ratings" : df["rating"].nunique(),
    "unique_genres"  : g["genre"].nunique(),
    "unique_countries": c["country_single"].nunique(),
    "year_min"       : int(df["year_added"].min()),
    "year_max"       : int(df["year_added"].max()),
    "avg_movie_mins" : round(df.loc[df["type"]=="Movie","duration_minutes"].mean(), 1),
}])
# Out:
# Building summary tables ...

# %%
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~jango (C:\Users\simra\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ltralytics (C:\Users\simra\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Error parsing dependencies of celery: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     pytz (>dev)
#          ~^
# WARNING: Ignoring invalid distribution ~jango (C:\Users\simra\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ltralytics (C:\Users\simra\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~jango (C:\Users\simra\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ltralytics (C:\Users\simra\AppData\Roaming\Python\Python312\site-packages)
# Requirement already satisfied: openpyxl in C:\Users\simra\AppData\Roaming\Python\Python312\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in C:\Users\simra\AppData\Roaming\Python\Python312\site-packages (from openpyxl) (1.1.0)

# %%
            # ── 11. EXPORT TO EXCEL ──────────────────────────────────────
print("++ to Excel ...")
with pd.ExcelWriter("netflix_for_excel.xlsx", engine="openpyxl") as writer:
    df.to_excel(writer,               sheet_name="Main_Data",          index=False)
    g.to_excel(writer,                sheet_name="Genres_Exploded",    index=False)
    c.to_excel(writer,                sheet_name="Countries_Exploded", index=False)
    yearly.to_excel(writer,           sheet_name="Yearly_Additions",   index=False)
    top_genres.to_excel(writer,       sheet_name="Top_Genres",         index=False)
    top_genres_yearly.to_excel(writer,sheet_name="Genres_Yearly",      index=False)
    top_countries.to_excel(writer,    sheet_name="Top_Countries",      index=False)
    rating_dist.to_excel(writer,      sheet_name="Rating_Dist",        index=False)
    monthly.to_excel(writer,          sheet_name="Monthly_Additions",  index=False)
    top_directors.to_excel(writer,    sheet_name="Top_Directors",      index=False)
    kpi.to_excel(writer,              sheet_name="KPI_Summary",        index=False)
print("  Saved netflix_for_excel.xlsx (11 sheets)")
# Out:
# ++ to Excel ...
#   Saved netflix_for_excel.xlsx (11 sheets)

# %%
# ── 12. SUMMARY ──────────────────────────────────────────────
print("\n=== STEP 1 COMPLETE ===")
print(f"Total clean titles  : {len(df):,}")
print(f"Movies              : {(df['type']=='Movie').sum():,}")
print(f"TV Shows            : {(df['type']=='TV Show').sum():,}")
print(f"Year range          : {int(df['year_added'].min())} - {int(df['year_added'].max())}")
print(f"Unique genres       : {g['genre'].nunique()}")
print(f"Unique countries    : {c['country_single'].nunique()}")
print("\nFiles created:")
print("  cleaned_netflix.csv")
print("  genres_exploded.csv")
print("  countries_exploded.csv")
print("  netflix_for_excel.xlsx  <- connect this to Power BI!")
# Out:
# === STEP 1 COMPLETE ===
# Total clean titles  : 7,682
# Movies              : 5,372
# TV Shows            : 2,310
# Year range          : 2008 - 2021
# Unique genres       : 42
# Unique countries    : 118
#
# Files created:
#   cleaned_netflix.csv
#   genres_exploded.csv
#   countries_exploded.csv
#   netflix_for_excel.xlsx  <- connect this to Power BI!
